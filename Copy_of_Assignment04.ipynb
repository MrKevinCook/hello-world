# %% [markdown]
# <a href="https://colab.research.google.com/github/MrKevinCook/hello-world/blob/master/Copy_of_Assignment04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Action Items:
# •	Create three different charts using Seaborn package.
#   1. Create three different meaningful charts using Seaborn package on your selected data set.
#   2. Explain when it is best to use
#   3. Submit your Python file

# %%
import pandas.testing as tm

# %%
import pandas as pand

# %%
df = pand.read_csv('https://raw.githubusercontent.com/frankData612/pandas_for_everyone/master/data/tesla_stock_yahoo.csv')

# %%
hist, ax = plt.subplots()

ax = sns.histplot(df['Volume'],kde=False)

ax.set_title('Volume and Price')

ax.set_xlabel('Volume in Millions')

ax.set_ylabel('High Price')

plt.show()

#Histogram that shows the high price and volume.
#That is, the correlation between volume and price movement.

# %%
dis, ax = plt.subplots()

ax = sns.distplot(df['Volume'], hist=False)

ax.set_title('Total Volume Density')

ax.set_xlabel('Volume in Millions')

ax.set_ylabel('Unit Probability')

plt.show()

#Denisty Plot to simply smooth out overlapping plots so the area under the curve is 1.
# Out:
# <ipython-input-24-7751419bcb96>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['Volume'], hist=False)

# %%
fig = sns.pairplot(df)

#Pairwise Relationships to plot a scatterplot between each variable.

# %%
pair_grid = sns.PairGrid(df)

pair_grid = pair_grid.map_upper(sns.regplot)

pair_grid = pair_grid.map_lower(sns.kdeplot)

pair_grid = pair_grid.map_diag(sns.distplot, rug=True)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...
